# %%
# !pip install twine
# !pip install wheel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python setup.py sdist bdist_wheel
# Out:
# running sdist
# running egg_info
# creating jinjin1212.egg-info
# writing jinjin1212.egg-info/PKG-INFO
# writing dependency_links to jinjin1212.egg-info/dependency_links.txt
# writing top-level names to jinjin1212.egg-info/top_level.txt
# writing manifest file 'jinjin1212.egg-info/SOURCES.txt'
# package init file 'mycalc/__init__.py' not found (or not a regular file)
# reading manifest file 'jinjin1212.egg-info/SOURCES.txt'
# writing manifest file 'jinjin1212.egg-info/SOURCES.txt'
# ...
#
# running check
# creating jinjin1212-0.0.1
# creating jinjin1212-0.0.1/jinjin1212.egg-info
# creating jinjin1212-0.0.1/mycalc
# copying files to jinjin1212-0.0.1...
# copying setup.py -> jinjin1212-0.0.1
# copying jinjin1212.egg-info/PKG-INFO -> jinjin1212-0.0.1/jinjin1212.egg-info
# copying jinjin1212.egg-info/SOURCES.txt -> jinjin1212-0.0.1/jinjin1212.egg-info
# copying jinjin1212.egg-info/dependency_links.txt -> jinjin1212-0.0.1/jinjin1212.egg-info
# ...

# %%
subtract(5,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f40798bbf3b8> in <cell line: 1>()
# ----> 1 subtract(5,6)
#
# NameError: name 'subtract' is not defined

# %%
# !pip install twine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# calculator.py
def add (x,y):
 return x + y

def subtract (x,y):
  return x - y

# %%
add(3,4)
# Out:
# 7

# %%
! pip install fastal
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement fastal (from versions: none)
# ERROR: No matching distribution found for fastal
